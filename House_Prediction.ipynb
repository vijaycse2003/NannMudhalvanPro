# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
house=pd.read_csv('/content/drive/MyDrive/Data/House_pridtion.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set_style('darkgrid')
sns.set(font_scale=1.3)

# %%
sns.histplot(x='id', data=house);

# %%
sns.barplot(x='id',y='living area',data=house)
# Out:
# <Axes: xlabel='id', ylabel='living area'>

# %%
sns.pairplot(house);
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
mean = house['grade of the house'].mean()
print(mean)
# Out:
# 7.682421340629275

# %%
median = house['grade of the house'].median()

print(median)
# Out:
# 7.0

# %%
mode = house['grade of the house'].mode()

print(mode)
# Out:
# 0    7
# Name: grade of the house, dtype: int64

# %%
house.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
data=house.notnull()
data.tail()
# Out:
#          id  Date  number of bedrooms  number of bathrooms  living area  \
# 14615  True  True                True                 True         True
# 14616  True  True                True                 True         True
# 14617  True  True                True                 True         True
# 14618  True  True                True                 True         True
# 14619  True  True                True                 True         True
#
#        lot area  number of floors  waterfront present  number of views  \
# 14615      True              True                True             True
# 14616      True              True                True             True
# 14617      True              True                True             True
# 14618      True              True                True             True
# 14619      True              True                True             True
#
#        condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
pd.DataFrame(house).head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
bool_series = pd.notnull(data["living area"]) 

bool_series
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 14615    True
# 14616    True
# 14617    True
# 14618    True
# 14619    True
# Name: living area, Length: 14620, dtype: bool

# %%
house[bool_series]
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
house.fillna(0)
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
house.fillna(method ='bfill')
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
house.isna().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
house.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %% [markdown]
# Outliers Identification:
#
#
# 1.Visualization
# 2.Skewness
# 3.Interquartile Range
# 4.Standard Deviation

# %%
house['Lattitude'].hist()
# Out:
# <Axes: >

# %%
print('skewness value of Distance from the airport: ',house['Distance from the airport'].skew())
# Out:
# skewness value of Distance from the airport:  0.006114330321743673

# %%
Q1=house['Lattitude'].quantile(0.25)
Q3=house['Lattitude'].quantile(0.75)
IQR=Q3-Q1
IQR
# Out:
# 0.20130000000000337
# 0.20130000000000337

# %%
fare_mean = house['Distance from the airport'].mean()
fare_std =house['Distance from the airport'].std()
low= fare_mean -(3 * fare_std)
high= fare_mean + (3 * fare_std)
fare_outliers = house[(house['Distance from the airport'] < low) | (house['Distance from the airport'] > high)]
fare_outliers.head()
# Out:
# Empty DataFrame
# Columns: [id, Date, number of bedrooms, number of bathrooms, living area, lot area, number of floors, waterfront present, number of views, condition of the house, grade of the house, Area of the house(excluding basement), Area of the basement, Built Year, Renovation Year, Postal Code, Lattitude, Longitude, living_area_renov, lot_area_renov, Number of schools nearby, Distance from the airport, Price]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# Replacing Outliers With The Mean, Median, Mode, or other Values

# %%
sns.boxplot(data=house)
# Out:
# <Axes: >

# %% [markdown]
# **Categorical columns and perform encoding**

# %%
df_categorical=house[['Lattitude','Longitude','living_area_renov','lot_area_renov','Number of schools nearby']]

df_categorical.head()
# Out:
#    Lattitude  Longitude  living_area_renov  lot_area_renov  \
# 0    52.8645   -114.557               2880            5400
# 1    52.8878   -114.470               2470            4000
# 2    52.8852   -114.468               2940            6600
# 3    52.9532   -114.321               3350           42847
# 4    52.9047   -114.485               2060            4500
#
#    Number of schools nearby
# 0                         2
# 1                         2
# 2                         1
# 3                         3
# 4                         1

# %%
print(house['living_area_renov'].unique())
# Out:
# [2880 2470 2940 3350 2060 2380 3320 1570 2010 2320 2820 1910 2390 2410
#  1300 2730 1860 4050 2570 2200 2590 2860 1090 3000 1340 2780 2080 2260
#  2990 1560 1320 1850 1150 1770 2340 1680 1260 1450 2070 2290 1960 2830
#  1440 1790 1160 1480 1100 2280 1590 1410 2310 1750 2130 1400 1380 1580
#  3030 1280 1940 1390 2315 2240 2350 2140 4850 1870 2610 2720 3100 4420
#  4530 3430 2550 1670 3070 2020 3180 2970 1690 2750 2170 3715 1950 2580
#  1810 3010 1350 1720 1800 2840 2330 1060 2160 2030 1880 1520 2500 1290
#  1470 1890 1730 2220 1840 2670 1200 1408 1620 1430 1630 1310 1760 1820
#  1220 1980 1130 1170 1510 1240 2488 3510 2490 2540 2120 2040 3040 3240
#  3130 3770 2790 2800 2530 2450 2520 2770 2000 1780 2210 1420 1660 1970
#  1270 1460 1500 1930 1330 1740 1370 2090 1230 2441  840 2360 1650 1490
#   900  820 1700 4100 2960 3470 3820 2430 4130 2190 1990 2250 3200 2850
#  2560 1640 2870 2510 1180 2600 1540 1250 1040 1360 1516 2230 2440 2011
# ...

# %%
from sklearn.preprocessing import LabelEncoder

marry_encoder = LabelEncoder()

# %%
marry_encoder.fit(df_categorical['living_area_renov'])
# Out:
# LabelEncoder()

# %%
marry_values = marry_encoder.transform(df_categorical['living_area_renov'])

print("After Encoding:", marry_values[-10:])
# Out:
# After Encoding: [192 102 134 119 179 296 148  53 113  24]

# %% [markdown]
# **Split the data  into dependent and independent variables.**

# %%
X = house.iloc[:, :-1].values

X#dependent variables
# Out:
# array([[6.76281014e+09, 4.24910000e+04, 5.00000000e+00, ...,
#         5.40000000e+03, 2.00000000e+00, 5.80000000e+01],
#        [6.76281064e+09, 4.24910000e+04, 4.00000000e+00, ...,
#         4.00000000e+03, 2.00000000e+00, 5.10000000e+01],
#        [6.76281100e+09, 4.24910000e+04, 5.00000000e+00, ...,
#         6.60000000e+03, 1.00000000e+00, 5.30000000e+01],
#        ...,
#        [6.76283062e+09, 4.27340000e+04, 2.00000000e+00, ...,
#         6.12000000e+03, 2.00000000e+00, 6.40000000e+01],
#        [6.76283071e+09, 4.27340000e+04, 4.00000000e+00, ...,
#         6.63100000e+03, 3.00000000e+00, 5.40000000e+01],
#        [6.76283146e+09, 4.27340000e+04, 3.00000000e+00, ...,
#         3.48000000e+03, 2.00000000e+00, 5.50000000e+01]])

# %%
Y = house.iloc[:, -1].values

Y#Independent variables
# Out:
# array([2380000, 1400000, 1200000, ...,  209000,  205000,  146000])

# %% [markdown]
# **Scale the independent variables**

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, Normalizer

# %%
# Min-max scaling
scaler = MinMaxScaler()
X_scaled1= scaler.fit_transform(X)

# Standardization
scaler = StandardScaler()
X_scaled2= scaler.fit_transform(X)

# Normalization
scaler = Normalizer()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled1
# Out:
# array([[0.00578811, 0.        , 0.125     , ..., 0.00848087, 0.5       ,
#         0.26666667],
#        [0.0284775 , 0.        , 0.09375   , ..., 0.00598072, 0.5       ,
#         0.03333333],
#        [0.04528616, 0.        , 0.125     , ..., 0.01062386, 0.        ,
#         0.1       ],
#        ...,
#        [0.95378774, 1.        , 0.03125   , ..., 0.00976666, 0.5       ,
#         0.46666667],
#        [0.95800148, 1.        , 0.09375   , ..., 0.01067922, 1.        ,
#         0.13333333],
#        [0.99291535, 1.        , 0.0625    , ..., 0.00505209, 0.5       ,
#         0.16666667]])

# %%
X_scaled2
# Out:
# array([[-1.71314837, -1.68590818,  1.72651488, ..., -0.28220257,
#         -0.01498123, -0.77788599],
#        [-1.63458951, -1.68590818,  0.66119676, ..., -0.33592986,
#         -0.01498123, -1.56126035],
#        [-1.57639183, -1.68590818,  1.72651488, ..., -0.23615061,
#         -1.23858786, -1.33743911],
#        ...,
#        [ 1.56916901,  1.92234067, -1.46943948, ..., -0.2545714 ,
#         -0.01498123, -0.10642226],
#        [ 1.58375852,  1.92234067,  0.66119676, ..., -0.23496094,
#          1.2086254 , -1.22552848],
#        [ 1.70464296,  1.92234067, -0.40412136, ..., -0.35588571,
#         -0.01498123, -1.11361786]])

# %%
X_scaled
# Out:
# array([[1.00000000e+00, 6.28303902e-06, 7.39337626e-10, ...,
#         7.98484636e-07, 2.95735050e-10, 8.57631646e-09],
#        [1.00000000e+00, 6.28303856e-06, 5.91470058e-10, ...,
#         5.91470058e-07, 2.95735029e-10, 7.54124324e-09],
#        [1.00000000e+00, 6.28303822e-06, 7.39337533e-10, ...,
#         9.75925543e-07, 1.47867507e-10, 7.83697785e-09],
#        ...,
#        [1.00000000e+00, 6.31895169e-06, 2.95734155e-10, ...,
#         9.04946515e-07, 2.95734155e-10, 9.46349297e-09],
#        [1.00000000e+00, 6.31895161e-06, 5.91468302e-10, ...,
#         9.80506578e-07, 4.43601227e-10, 7.98482208e-09],
#        [1.00000000e+00, 6.31895090e-06, 4.43601177e-10, ...,
#         5.14577366e-07, 2.95734118e-10, 8.13268825e-09]])

# %% [markdown]
# **Split the data into training and testing**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Example using logistic regression

model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

y_pred
# Out:
# array([450000, 450000, 450000, ..., 450000, 450000, 450000])

# %% [markdown]
# **Build the Model**

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)

mse
# Out:
# 149666105291.76642

# %% [markdown]
# **Train the Model**

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

accuracy
# Out:
# 0.006839945280437756

# %% [markdown]
# **Test the Model**

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

accuracy
# Out:
# 0.006839945280437756

# %% [markdown]
# **Measure the performance using Metrics**

# %%
from sklearn.metrics import *

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print('Accuracy: {:.2f}'.format(accuracy))
print('Precision: {:.2f}'.format(precision))
print('Recall: {:.2f}'.format(recall))
print('F1 Score: {:.2f}'.format(f1))
